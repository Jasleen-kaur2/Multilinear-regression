# %% [markdown]
# # Student performance prediction

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/jasleen kaur/OneDrive/Desktop/DS_ML/regression dataset.csv")
df
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1                 91
# 1                                    2                 65
# 2                                    2                 45
# 3                                    2                 36
# 4                                    5                 66
# ...

# %% [markdown]
# # Analysis

# %%
df.shape
# Out:
# (10000, 5)

# %%
df.size
# Out:
# 50000

# %%
df.count()
# Out:
# Hours Studied                       10000
# Previous Scores                     10000
# Sleep Hours                         10000
# Sample Question Papers Practiced    10000
# Performance Index                   10000
# dtype: int64

# %%
df.min()
# Out:
# Hours Studied                        1
# Previous Scores                     40
# Sleep Hours                          4
# Sample Question Papers Practiced     0
# Performance Index                   10
# dtype: int64

# %%
df.max()
# Out:
# Hours Studied                         9
# Previous Scores                      99
# Sleep Hours                           9
# Sample Question Papers Practiced      9
# Performance Index                   100
# dtype: int64

# %%
df.mean()
# Out:
# Hours Studied                        4.9929
# Previous Scores                     69.4457
# Sleep Hours                          6.5306
# Sample Question Papers Practiced     4.5833
# Performance Index                   55.2248
# dtype: float64

# %%
df.median()
# Out:
# Hours Studied                        5.0
# Previous Scores                     69.0
# Sleep Hours                          7.0
# Sample Question Papers Practiced     5.0
# Performance Index                   55.0
# dtype: float64

# %%
df.std()
# Out:
# Hours Studied                        2.589309
# Previous Scores                     17.343152
# Sleep Hours                          1.695863
# Sample Question Papers Practiced     2.867348
# Performance Index                   19.212558
# dtype: float64

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Sleep Hours  \
# 0              7               99            9
# 1              4               82            4
# 2              8               51            7
# 3              5               52            5
# 4              7               75            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1                 91
# 1                                 2                 65
# 2                                 2                 45
# 3                                 2                 36
# 4                                 5                 66

# %%
df.tail()
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2                 23
# 9996                                 5                 58
# 9997                                 5                 74
# 9998                                 0                 95
# 9999                                 1                 64

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Scatter plot

# %%
sns.scatterplot(x='Hours Studied',y='Performance Index',data=df)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
sns.scatterplot(x='Previous Scores',y='Performance Index',data=df)
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Performance Index'>

# %%
sns.scatterplot(x='Sleep Hours',y='Performance Index',data=df)
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Performance Index'>

# %%
sns.scatterplot(x='Sample Question Papers Practiced',y='Performance Index',data=df)
# Out:
# <Axes: xlabel='Sample Question Papers Practiced', ylabel='Performance Index'>

# %% [markdown]
# ### Regression plot

# %%
sns.regplot(x='Hours Studied',y='Performance Index',data=df)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
sns.regplot(x='Previous Scores',y='Performance Index',data=df)
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Performance Index'>

# %%
sns.regplot(x='Sleep Hours',y='Performance Index',data=df)
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Performance Index'>

# %%
sns.regplot(x='Sample Question Papers Practiced',y='Performance Index',data=df)
# Out:
# <Axes: xlabel='Sample Question Papers Practiced', ylabel='Performance Index'>

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(y='Sample Question Papers Practiced',data=df)
# Out:
# <Axes: ylabel='Sample Question Papers Practiced'>

# %%
sns.boxplot(y='Sleep Hours',data=df)
# Out:
# <Axes: ylabel='Sleep Hours'>

# %%
sns.boxplot(y='Performance Index',data=df)
# Out:
# <Axes: ylabel='Performance Index'>

# %%
sns.boxplot(y='Previous Scores',data=df)
# Out:
# <Axes: ylabel='Previous Scores'>

# %% [markdown]
# ### so, no outliers

# %% [markdown]
# # Finding null values

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %% [markdown]
# ### no null values

# %% [markdown]
# # Duplicated values

# %%
df.duplicated().sum()
# Out:
# 234

# %% [markdown]
# ### removing duplicated values

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1                 91
# 1                                    2                 65
# 2                                    2                 45
# 3                                    2                 36
# 4                                    5                 66
# ...

# %%
df=df.reset_index()

# %%
df
# Out:
#       index  Hours Studied  Previous Scores  Sleep Hours  \
# 0         0              7               99            9
# 1         1              4               82            4
# 2         2              8               51            7
# 3         3              5               52            5
# 4         4              7               75            8
# ...     ...            ...              ...          ...
# 9761   9995              1               49            4
# 9762   9996              7               64            8
# 9763   9997              6               83            8
# 9764   9998              9               97            7
# 9765   9999              7               74            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1                 91
# 1                                    2                 65
# 2                                    2                 45
# ...

# %%
df.drop(columns=['index'],inplace=True)

# %%
df
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9761              1               49            4
# 9762              7               64            8
# 9763              6               83            8
# 9764              9               97            7
# 9765              7               74            8
#
#       Sample Question Papers Practiced  Performance Index
# 0                                    1                 91
# 1                                    2                 65
# 2                                    2                 45
# 3                                    2                 36
# 4                                    5                 66
# ...

# %% [markdown]
# ### duplicates are removed

# %% [markdown]
# # Split x and y

# %%
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9761              1               49            4
# 9762              7               64            8
# 9763              6               83            8
# 9764              9               97            7
# 9765              7               74            8
#
#       Sample Question Papers Practiced
# 0                                    1
# 1                                    2
# 2                                    2
# 3                                    2
# 4                                    5
# ...                                ...
# 9761                                 2
# 9762                                 5
# ...

# %%
y
# Out:
# 0       91
# 1       65
# 2       45
# 3       36
# 4       66
#         ..
# 9761    23
# 9762    58
# 9763    74
# 9764    95
# 9765    64
# Name: Performance Index, Length: 9766, dtype: int64

# %% [markdown]
# ## More visualizations

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
##train test and learn- websites-
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(x,y,random_state=42,test_size=0.25) 
#random_state-cycle tht goes till the 80:20 ratio is acieved,
#test_size-it divides the model in 80:20 test and train

# %%
x_train
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 8283              2               54            5
# 2663              3               65            8
# 6127              1               50            6
# 6110              5               87            6
# 2894              3               46            8
# ...             ...              ...          ...
# 5734              7               62            9
# 5191              4               96            6
# 5390              9               46            8
# 860               7               42            8
# 7270              5               82            7
#
#       Sample Question Papers Practiced
# 8283                                 9
# 2663                                 3
# 6127                                 6
# 6110                                 9
# 2894                                 4
# ...                                ...
# 5734                                 2
# 5191                                 1
# ...

# %%
y_train
# Out:
# 8283    28
# 2663    47
# 6127    22
# 6110    76
# 2894    26
#         ..
# 5734    55
# 5191    77
# 5390    41
# 860     33
# 7270    68
# Name: Performance Index, Length: 7324, dtype: int64

# %%
x_test
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 2088              4               42            6
# 3002              5               66            6
# 6603              3               82            8
# 4053              7               47            5
# 3555              2               77            4
# ...             ...              ...          ...
# 3148              6               54            4
# 3244              8               91            8
# 6501              9               55            7
# 7226              1               54            5
# 9532              4               86            6
#
#       Sample Question Papers Practiced
# 2088                                 0
# 3002                                 8
# 6603                                 6
# 4053                                 7
# 3555                                 5
# ...                                ...
# 3148                                 5
# 3244                                 1
# ...

# %%
y_test
# Out:
# 2088    27
# 3002    51
# 6603    63
# 4053    38
# 3555    51
#         ..
# 3148    39
# 3244    87
# 6501    52
# 7226    29
# 9532    69
# Name: Performance Index, Length: 2442, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler 
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[-1.16994379, -0.89514527, -0.90496399,  1.53369794],
#        [-0.78260683, -0.26062986,  0.85966761, -0.55031017],
#        [-1.55728076, -1.12587815, -0.31675346,  0.49169388],
#        ...,
#        [ 1.54141496, -1.35661103,  0.85966761,  0.1443592 ],
#        [ 0.76674103, -1.58734391,  0.85966761,  1.53369794],
#        [-0.0079329 ,  0.71998487,  0.27145707,  1.18636325]])

# %%
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[-0.39526986, -1.58734391, -0.31675346, -1.59231422],
#        [-0.0079329 , -0.20294664, -0.31675346,  1.18636325],
#        [-0.78260683,  0.71998487,  0.85966761,  0.49169388],
#        ...,
#        [ 1.54141496, -0.83746205,  0.27145707, -0.55031017],
#        [-1.55728076, -0.89514527, -0.90496399, -1.24497954],
#        [-0.39526986,  0.95071775, -0.31675346,  1.18636325]])

# %%
#made regression model
from sklearn.linear_model import LinearRegression
regression=LinearRegression(n_jobs=-1)

# %%
regression.fit(x_train,y_train)
regression
# Out:
# LinearRegression(n_jobs=-1)

# %%
##prediction- value came from out model is stored in y_pred
y_pred=regression.predict(x_test)

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)#comparin gvalue that came with value that should come
print(score)
# Out:
# 0.9887809564661459

# %%
##prediction of new data
regression.predict([[8,51,7,2]])
# Out:
# array([1021.93274479])

# %%
regression.predict(scaler.transform([[8,51,7,2]]))
# Out:
# C:\Users\jasleen kaur\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([44.7374153])
